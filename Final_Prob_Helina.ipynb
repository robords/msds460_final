# %%
from pulp import LpVariable, LpProblem, LpMaximize, LpStatus, value, LpMinimize, GLPK
from itertools import permutations
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_colwidth', None)

# %%
# definevariables
factories = ['A', 'B']
productions = ['widgets', 'gadgets', 'flugels']
time_periods = [1, 2, 3, 4, 5]
# Create all permuations of the production decision variables
production_combinations = {(f, p, t): LpVariable(f"factory{f}_{p}_{t}", 0, None, cat='Integer')
                           for f in factories for p in productions for t in time_periods}

storage_combinations = {(f, p, t): LpVariable(f"storage_factory{f}_{p}_{t}", 0, 0 if t==5 else None, cat='Integer')
                                              for f in factories for p in productions for t in time_periods}
                         
marketing_combinations = {(p, t): LpVariable(f"marketing_{p}_{t}", 0, None, cat='Integer')
                          for p in productions for t in time_periods[:-1]} 
                                              
overtime_combinations = {(f, t): LpVariable(f"overtime_factory{f}_{t}", 0, None)
                         for f in factories for t in time_periods}

# %%
def get_production(factory = None, production = None, time_period = None):
    """
    Helper function for grabbing multiple production variables when needed
    """
    factory = [factory] if factory else factories
    production = [production] if production else productions
    time_period = [time_period] if time_period else time_periods
    
    return [production_combinations[(f, p, t)] for f in factory for p in production for t in time_period]

# %%
# Aggregate across time periods
factoryA_widgets = sum(get_production("A", "widgets"))
factoryB_widgets = sum(get_production("B", "widgets"))
factoryA_gadgets = sum(get_production("A", "gadgets"))
factoryB_gadgets = sum(get_production("B", "gadgets"))
factoryA_flugels = sum(get_production("A", "flugels"))
factoryB_flugels = sum(get_production("B", "flugels"))
widgets = sum(get_production(production = "widgets"))
gadgets = sum(get_production(production = "gadgets"))
flugels = sum(get_production(production = "flugels"))

# %%
# All the aggregations of raw material 1 & 2
material_costs = {
    ("A", "widgets", 1): 194,
    ("A", "gadgets", 1): 230,
    ("A", "flugels", 1): 178,
    ("A", "widgets", 2): 8.6,
    ("A", "gadgets", 2): 0,
    ("A", "flugels", 2): 11.6,
    ("B", "widgets", 1): 188,
    ("B", "gadgets", 1): 225,
    ("B", "flugels", 1): 170,
    ("B", "widgets", 2): 9.2,
    ("B", "gadgets", 2): 0,
    ("B", "flugels", 2): 10.8,
}
materials_used = {}
for t in time_periods:
    for material in [1, 2]:
        used_amount = sum([get_production(factory, production, t)[0] * material_costs[(factory, production, material)]
                           for factory in factories for production in productions])
        
        materials_used.update({(t, material): used_amount})
factoryA_material1 = 194 * factoryA_widgets + 230 * factoryA_gadgets + 178 * factoryA_flugels
factoryA_material2 = 8.6 * factoryA_widgets + 0 * factoryA_gadgets + 11.6 * factoryA_flugels
factoryB_material1 = 188 * factoryB_widgets + 9.2 * factoryB_gadgets + 9.1 * factoryB_flugels
factoryB_material2 = 9.2 * factoryB_widgets + 0 * factoryB_gadgets + 10.8 * factoryB_flugels

# %%
# All the aggregations of labor
factoryA_labors = {}
factoryB_labors = {}
for t in time_periods:
    
    factoryA_labor = (
        9.5 * get_production("A", "widgets", t)[0] +
        7.1 * get_production("A", "gadgets", t)[0] +
        11.1 * get_production("A", "flugels", t)[0]
    )
    factoryB_labor = (
        9.1 * get_production("B", "widgets", t)[0] +
        7.8 * get_production("B", "gadgets", t)[0] +
        10.6 * get_production("B", "flugels", t)[0]
    )
    
    factoryA_labors.update({t: factoryA_labor})
    factoryB_labors.update({t: factoryB_labor})

# %%
# All the aggregations of demand    
# Marketing has indexes off by one because there is a delay for it to take affect
demands = {
    ('widgets', 1): 70,
    ('widgets', 2): 125 + marketing_combinations[('widgets', 1)],
    ('widgets', 3): 185 + marketing_combinations[('widgets', 2)],
    ('widgets', 4): 190 + marketing_combinations[('widgets', 3)],
    ('widgets', 5): 200 + marketing_combinations[('widgets', 4)],
    ('gadgets', 1): 200,
    ('gadgets', 2): 300 + marketing_combinations[('gadgets', 1)],
    ('gadgets', 3): 295 + marketing_combinations[('gadgets', 2)],
    ('gadgets', 4): 245 + marketing_combinations[('gadgets', 3)],
    ('gadgets', 5): 240 + marketing_combinations[('gadgets', 4)],
    ('flugels', 1): 140,
    ('flugels', 2): 175 + marketing_combinations[('flugels', 1)],
    ('flugels', 3): 205 + marketing_combinations[('flugels', 2)],
    ('flugels', 4): 235 + marketing_combinations[('flugels', 3)],
    ('flugels', 5): 230 + marketing_combinations[('flugels', 4)]
}

# %%
#Calculate Cashflows
sales_revenue = (
    2490 * widgets +
    1990 * gadgets +
    2970 * flugels
)
shipping_costs = (
    6.3 * factoryA_widgets +
    6.5 * factoryB_widgets +
    4.6 * factoryA_gadgets +
    5 * factoryB_gadgets +
    5.5 * factoryA_flugels +
    5.7 * factoryB_flugels
)
costs = {
    ('A', 'widgets'): 7.5,
    ('A', 'gadgets'): 5.5,
    ('A', 'flugels'): 6.5,
    ('B', 'widgets'): 7.8,
    ('B', 'gadgets'): 5.7,
    ('B', 'flugels'): 7.0,
}
storage_costs = sum([costs[(key[0], key[1])] * value for key, value in storage_combinations.items()])
labor_costs = 11 * (
    factoryA_labors[1] +
    factoryA_labors[2] +
    1.05 * factoryA_labors[3] +
    1.05 * factoryA_labors[4] +
    1.05 * factoryA_labors[5] +
    factoryB_labors[1] +
    factoryB_labors[2] +
    1.1 * factoryB_labors[3] +
    1.1 * factoryB_labors[4] +
    1.1 * factoryB_labors[5]
)
# Overtime costs, only includes marginal extra cost, not the full cost of labor
overtime_costs = 5.5 * (
    overtime_combinations[("A", 1)] +
    overtime_combinations[("A", 2)] +
    1.05 * overtime_combinations[("A", 3)] +
    1.05 * overtime_combinations[("A", 4)] +
    1.05 * overtime_combinations[("A", 5)] +
    overtime_combinations[("B", 1)] +
    overtime_combinations[("B", 2)] +
    1.1 * overtime_combinations[("B", 3)] +
    1.1 * overtime_combinations[("B", 4)] +
    1.1 * overtime_combinations[("B", 5)]
)
material_costs = (
    1.25 * factoryA_material1 +
    2.65 * factoryA_material2 +
    1.45 * factoryB_material1 +
    2.9 * factoryB_material2
)
get_marketing = lambda prod: sum([val for key, val in marketing_combinations.items() if key[0] == prod])
marketing_costs = (
    160 * get_marketing("widgets") +
    120 * get_marketing("gadgets") +
    180 * get_marketing("flugels")
)
cash = (sales_revenue - (shipping_costs + labor_costs + overtime_costs + 
                         storage_costs + material_costs + marketing_costs))

# %%
#create constraints
constraints = {
    "Marketing Budget": marketing_costs <= 70_000
}
# Labor required to produce must be less than labor available
for t, labor in factoryA_labors.items():
    constraints.update({f"Factory A, Time {t} - Labor met by standard and overtime": labor <= 2500 + overtime_costs})
    
for t, labor in factoryB_labors.items():
    constraints.update({f"Factory B, Time {t} - Labor met by standard and overtime": labor <= 3800 + overtime_costs})
# Exactly meet demand in all time periods
for key, demand in demands.items():
    production = key[0]
    t = key[1]
    
    prod_a = sum(get_production("A", production, t))
    prod_b = sum(get_production("B", production, t))
    object_count = sum(get_production(production = production, time_period = t))    
    stor_a = storage_combinations[("A", production, t)]
    stor_b = storage_combinations[("B", production, t)]
        
    if t == 1:
        # We've got to "use up" all the production and previously stored stuff
        constraints.update({f"Inflows and Outflows of Production Equal - {production} - time {t}":
                            object_count == demand + stor_a + stor_b})
        
        # We've got to make sure we only store/use from locations that have supply available
        constraints.update({f"Inflows Balanced for Factory A - {production} - time {t}":
                            prod_a >= stor_a})
        constraints.update({f"Inflows Balanced for Factory B - {production} - time {t}":
                            prod_b >= stor_b})
    else:
        # Pick up storage from last cycle
        last_stor_a = storage_combinations[("A", production, t - 1)]
        last_stor_b = storage_combinations[("B", production, t - 1)]
        
        # We've got to "use up" all the production and previously stored stuff
        constraints.update({f"Inflows and Outflows of Production Equal - {production} - time {t}":
                            object_count + last_stor_a + last_stor_b == demand + stor_a + stor_b})
        
        # We've got to make sure we only store/use from locations that have supply available
        constraints.update({f"Inflows Balanced for Factory A - {production} - time {t}":
                            prod_a >= stor_a - last_stor_a})
        constraints.update({f"Inflows Balanced for Factory B - {production} - time {t}":
                            prod_b >= stor_b - last_stor_b})
# Storage Limits
for f in factories:
    for t in time_periods:
        stor = sum(val for key, val in storage_combinations.items() if (key[0] == f) and (key[2] == t))
        limit = (70 if f == 'A' else 50)
        
        constraints.update({f"Factory {f} Storage limit - time {t}": stor <= limit})
    
    
# Raw Material limits
for key, amount in materials_used.items():
    t = key[0]
    material = key[1]
    
    # Constraint is provided in tons, so multiply by 2000
    (constraints.update({f'Raw Material {material} Limits - time {t}': amount <= 
                         (70*2000 if material == 1 else 2.5*2000)}))

# %%
#define problem
prob = LpProblem("problem", LpMaximize)
prob += cash
# Looping through all the constraints to add them ﴾pass a tupple to name them﴿
for name, constraint in constraints.items():
    prob += constraint, name

# %% [markdown]
# ### trying time limit
# ### Next try removing the integer requirements

# %%
#solve problem
#prob.solve()
prob.solve(GLPK(msg=0, options=['--ranges', 'final_prob.sen', '--tmlim', '1500']))
print(f"Objective = {value(prob.objective):,.2f}")
print(f"")
print(prob)
print("")
print("Parameter Set")
# print the results
o = [{'Name': variable.name, 'Optimal Value': variable.varValue} for variable in prob.variables()]
display(pd.DataFrame(o))
# Out:
# Objective = 7,775,749.41
#
# problem:
# MAXIMIZE
# 2589.16*factoryA_flugels_1 + 2589.16*factoryA_flugels_2 + 2583.055*factoryA_flugels_3 + 2583.055*factoryA_flugels_4 + 2583.055*factoryA_flugels_5 + 1619.8*factoryA_gadgets_1 + 1619.8*factoryA_gadgets_2 + 1615.895*factoryA_gadgets_3 + 1615.895*factoryA_gadgets_4 + 1615.895*factoryA_gadgets_5 + 2113.91*factoryA_widgets_1 + 2113.91*factoryA_widgets_2 + 2108.685*factoryA_widgets_3 + 2108.685*factoryA_widgets_4 + 2108.685*factoryA_widgets_5 + 2803.185*factoryB_flugels_1 + 2803.185*factoryB_flugels_2 + 2791.525*factoryB_flugels_3 + 2791.525*factoryB_flugels_4 + 2791.525*factoryB_flugels_5 + 1885.86*factoryB_gadgets_1 + 1885.86*factoryB_gadgets_2 + 1877.28*factoryB_gadgets_3 + 1877.28*factoryB_gadgets_4 + 1877.28*factoryB_gadgets_5 + 2084.12*factoryB_widgets_1 + 2084.12*factoryB_widgets_2 + 2074.11*factoryB_widgets_3 + 2074.11*factoryB_widgets_4 + 2074.11*factoryB_widgets_5 + -180*marketing_flugels_1 + -180*marketing_flugels_2 + -180*marketing_flugels_3 + -180*marketing_flugels_4 + -120*marketing_gadgets_1 + -120*marketing_gadgets_2 + -120*marketing_gadgets_3 + -120*marketing_gadgets_4 + -160*marketing_widgets_1 + -160*marketing_widgets_2 + -160*marketing_widgets_3 + -160*marketing_widgets_4 + -5.5*overtime_factoryA_1 + -5.5*overtime_factoryA_2 + -5.775*overtime_factoryA_3 + -5.775*overtime_factoryA_4 + -5.775*overtime_factoryA_5 + -5.5*overtime_factoryB_1 + -5.5*overtime_factoryB_2 + -6.050000000000001*overtime_factoryB_3 + -6.050000000000001*overtime_factoryB_4 + -6.050000000000001*overtime_factoryB_5 + -6.5*storage_factoryA_flugels_1 + -6.5*storage_factoryA_flugels_2 + -6.5*storage_factoryA_flugels_3 + -6.5*storage_factoryA_flugels_4 + -6.5*storage_factoryA_flugels_5 + -5.5*storage_factoryA_gadgets_1 + -5.5*storage_factoryA_gadgets_2 + -5.5*storage_factoryA_gadgets_3 + -5.5*storage_factoryA_gadgets_4 + -5.5*storage_factoryA_gadgets_5 + -7.5*storage_factoryA_widgets_1 + -7.5*storage_factoryA_widgets_2 + -7.5*storage_factoryA_widgets_3 + -7.5*storage_factoryA_widgets_4 + -7.5*storage_factoryA_widgets_5 + -7.0*storage_factoryB_flugels_1 + -7.0*storage_factoryB_flugels_2 + -7.0*storage_factoryB_flugels_3 + -7.0*storage_factoryB_flugels_4 + -7.0*storage_factoryB_flugels_5 + -5.7*storage_factoryB_gadgets_1 + -5.7*storage_factoryB_gadgets_2 + -5.7*storage_factoryB_gadgets_3 + -5.7*storage_factoryB_gadgets_4 + -5.7*storage_factoryB_gadgets_5 + -7.8*storage_factoryB_widgets_1 + -7.8*storage_factoryB_widgets_2 + -7.8*storage_factoryB_widgets_3 + -7.8*storage_factoryB_widgets_4 + -7.8*storage_factoryB_widgets_5 + 0.0
# SUBJECT TO
# Marketing_Budget: 180 marketing_flugels_1 + 180 marketing_flugels_2
#  + 180 marketing_flugels_3 + 180 marketing_flugels_4 + 120 marketing_gadgets_1
#  + 120 marketing_gadgets_2 + 120 marketing_gadgets_3 + 120 marketing_gadgets_4
#  + 160 marketing_widgets_1 + 160 marketing_widgets_2 + 160 marketing_widgets_3
#  + 160 marketing_widgets_4 <= 70000
#
# Factory_A,_Time_1___Labor_met_by_standard_and_overtime:
#  11.1 factoryA_flugels_1 + 7.1 factoryA_gadgets_1 + 9.5 factoryA_widgets_1
#  - 5.5 overtime_factoryA_1 - 5.5 overtime_factoryA_2
#  - 5.775 overtime_factoryA_3 - 5.775 overtime_factoryA_4
#  - 5.775 overtime_factoryA_5 - 5.5 overtime_factoryB_1
#  - 5.5 overtime_factoryB_2 - 6.05 overtime_factoryB_3
#  - 6.05 overtime_factoryB_4 - 6.05 overtime_factoryB_5 <= 2500
#
# Factory_A,_Time_2___Labor_met_by_standard_and_overtime:
#  11.1 factoryA_flugels_2 + 7.1 factoryA_gadgets_2 + 9.5 factoryA_widgets_2
#  - 5.5 overtime_factoryA_1 - 5.5 overtime_factoryA_2
#  - 5.775 overtime_factoryA_3 - 5.775 overtime_factoryA_4
#  - 5.775 overtime_factoryA_5 - 5.5 overtime_factoryB_1
#  - 5.5 overtime_factoryB_2 - 6.05 overtime_factoryB_3
#  - 6.05 overtime_factoryB_4 - 6.05 overtime_factoryB_5 <= 2500
#
# Factory_A,_Time_3___Labor_met_by_standard_and_overtime:
#  11.1 factoryA_flugels_3 + 7.1 factoryA_gadgets_3 + 9.5 factoryA_widgets_3
#  - 5.5 overtime_factoryA_1 - 5.5 overtime_factoryA_2
#  - 5.775 overtime_factoryA_3 - 5.775 overtime_factoryA_4
#  - 5.775 overtime_factoryA_5 - 5.5 overtime_factoryB_1
#  - 5.5 overtime_factoryB_2 - 6.05 overtime_factoryB_3
#  - 6.05 overtime_factoryB_4 - 6.05 overtime_factoryB_5 <= 2500
#
# Factory_A,_Time_4___Labor_met_by_standard_and_overtime:
#  11.1 factoryA_flugels_4 + 7.1 factoryA_gadgets_4 + 9.5 factoryA_widgets_4
#  - 5.5 overtime_factoryA_1 - 5.5 overtime_factoryA_2
#  - 5.775 overtime_factoryA_3 - 5.775 overtime_factoryA_4
#  - 5.775 overtime_factoryA_5 - 5.5 overtime_factoryB_1
#  - 5.5 overtime_factoryB_2 - 6.05 overtime_factoryB_3
#  - 6.05 overtime_factoryB_4 - 6.05 overtime_factoryB_5 <= 2500
#
# Factory_A,_Time_5___Labor_met_by_standard_and_overtime:
#  11.1 factoryA_flugels_5 + 7.1 factoryA_gadgets_5 + 9.5 factoryA_widgets_5
#  - 5.5 overtime_factoryA_1 - 5.5 overtime_factoryA_2
#  - 5.775 overtime_factoryA_3 - 5.775 overtime_factoryA_4
#  - 5.775 overtime_factoryA_5 - 5.5 overtime_factoryB_1
#  - 5.5 overtime_factoryB_2 - 6.05 overtime_factoryB_3
#  - 6.05 overtime_factoryB_4 - 6.05 overtime_factoryB_5 <= 2500
#
# Factory_B,_Time_1___Labor_met_by_standard_and_overtime:
#  10.6 factoryB_flugels_1 + 7.8 factoryB_gadgets_1 + 9.1 factoryB_widgets_1
#  - 5.5 overtime_factoryA_1 - 5.5 overtime_factoryA_2
#  - 5.775 overtime_factoryA_3 - 5.775 overtime_factoryA_4
#  - 5.775 overtime_factoryA_5 - 5.5 overtime_factoryB_1
#  - 5.5 overtime_factoryB_2 - 6.05 overtime_factoryB_3
#  - 6.05 overtime_factoryB_4 - 6.05 overtime_factoryB_5 <= 3800
#
# Factory_B,_Time_2___Labor_met_by_standard_and_overtime:
#  10.6 factoryB_flugels_2 + 7.8 factoryB_gadgets_2 + 9.1 factoryB_widgets_2
#  - 5.5 overtime_factoryA_1 - 5.5 overtime_factoryA_2
#  - 5.775 overtime_factoryA_3 - 5.775 overtime_factoryA_4
#  - 5.775 overtime_factoryA_5 - 5.5 overtime_factoryB_1
#  - 5.5 overtime_factoryB_2 - 6.05 overtime_factoryB_3
#  - 6.05 overtime_factoryB_4 - 6.05 overtime_factoryB_5 <= 3800
#
# Factory_B,_Time_3___Labor_met_by_standard_and_overtime:
#  10.6 factoryB_flugels_3 + 7.8 factoryB_gadgets_3 + 9.1 factoryB_widgets_3
#  - 5.5 overtime_factoryA_1 - 5.5 overtime_factoryA_2
#  - 5.775 overtime_factoryA_3 - 5.775 overtime_factoryA_4
#  - 5.775 overtime_factoryA_5 - 5.5 overtime_factoryB_1
#  - 5.5 overtime_factoryB_2 - 6.05 overtime_factoryB_3
#  - 6.05 overtime_factoryB_4 - 6.05 overtime_factoryB_5 <= 3800
#
# Factory_B,_Time_4___Labor_met_by_standard_and_overtime:
#  10.6 factoryB_flugels_4 + 7.8 factoryB_gadgets_4 + 9.1 factoryB_widgets_4
#  - 5.5 overtime_factoryA_1 - 5.5 overtime_factoryA_2
#  - 5.775 overtime_factoryA_3 - 5.775 overtime_factoryA_4
#  - 5.775 overtime_factoryA_5 - 5.5 overtime_factoryB_1
#  - 5.5 overtime_factoryB_2 - 6.05 overtime_factoryB_3
#  - 6.05 overtime_factoryB_4 - 6.05 overtime_factoryB_5 <= 3800
#
# Factory_B,_Time_5___Labor_met_by_standard_and_overtime:
#  10.6 factoryB_flugels_5 + 7.8 factoryB_gadgets_5 + 9.1 factoryB_widgets_5
#  - 5.5 overtime_factoryA_1 - 5.5 overtime_factoryA_2
#  - 5.775 overtime_factoryA_3 - 5.775 overtime_factoryA_4
#  - 5.775 overtime_factoryA_5 - 5.5 overtime_factoryB_1
#  - 5.5 overtime_factoryB_2 - 6.05 overtime_factoryB_3
#  - 6.05 overtime_factoryB_4 - 6.05 overtime_factoryB_5 <= 3800
#
# Inflows_and_Outflows_of_Production_Equal___widgets___time_1:
#  factoryA_widgets_1 + factoryB_widgets_1 - storage_factoryA_widgets_1
#  - storage_factoryB_widgets_1 = 70
#
# Inflows_Balanced_for_Factory_A___widgets___time_1: factoryA_widgets_1
#  - storage_factoryA_widgets_1 >= 0
#
# Inflows_Balanced_for_Factory_B___widgets___time_1: factoryB_widgets_1
#  - storage_factoryB_widgets_1 >= 0
#
# Inflows_and_Outflows_of_Production_Equal___widgets___time_2:
#  factoryA_widgets_2 + factoryB_widgets_2 - marketing_widgets_1
#  + storage_factoryA_widgets_1 - storage_factoryA_widgets_2
#  + storage_factoryB_widgets_1 - storage_factoryB_widgets_2 = 125
#
# Inflows_Balanced_for_Factory_A___widgets___time_2: factoryA_widgets_2
#  + storage_factoryA_widgets_1 - storage_factoryA_widgets_2 >= 0
#
# Inflows_Balanced_for_Factory_B___widgets___time_2: factoryB_widgets_2
#  + storage_factoryB_widgets_1 - storage_factoryB_widgets_2 >= 0
#
# Inflows_and_Outflows_of_Production_Equal___widgets___time_3:
#  factoryA_widgets_3 + factoryB_widgets_3 - marketing_widgets_2
#  + storage_factoryA_widgets_2 - storage_factoryA_widgets_3
#  + storage_factoryB_widgets_2 - storage_factoryB_widgets_3 = 185
#
# Inflows_Balanced_for_Factory_A___widgets___time_3: factoryA_widgets_3
#  + storage_factoryA_widgets_2 - storage_factoryA_widgets_3 >= 0
#
# Inflows_Balanced_for_Factory_B___widgets___time_3: factoryB_widgets_3
#  + storage_factoryB_widgets_2 - storage_factoryB_widgets_3 >= 0
#
# Inflows_and_Outflows_of_Production_Equal___widgets___time_4:
#  factoryA_widgets_4 + factoryB_widgets_4 - marketing_widgets_3
#  + storage_factoryA_widgets_3 - storage_factoryA_widgets_4
#  + storage_factoryB_widgets_3 - storage_factoryB_widgets_4 = 190
#
# Inflows_Balanced_for_Factory_A___widgets___time_4: factoryA_widgets_4
#  + storage_factoryA_widgets_3 - storage_factoryA_widgets_4 >= 0
#
# Inflows_Balanced_for_Factory_B___widgets___time_4: factoryB_widgets_4
#  + storage_factoryB_widgets_3 - storage_factoryB_widgets_4 >= 0
#
# Inflows_and_Outflows_of_Production_Equal___widgets___time_5:
#  factoryA_widgets_5 + factoryB_widgets_5 - marketing_widgets_4
#  + storage_factoryA_widgets_4 - storage_factoryA_widgets_5
#  + storage_factoryB_widgets_4 - storage_factoryB_widgets_5 = 200
#
# Inflows_Balanced_for_Factory_A___widgets___time_5: factoryA_widgets_5
#  + storage_factoryA_widgets_4 - storage_factoryA_widgets_5 >= 0
#
# Inflows_Balanced_for_Factory_B___widgets___time_5: factoryB_widgets_5
#  + storage_factoryB_widgets_4 - storage_factoryB_widgets_5 >= 0
#
# Inflows_and_Outflows_of_Production_Equal___gadgets___time_1:
#  factoryA_gadgets_1 + factoryB_gadgets_1 - storage_factoryA_gadgets_1
#  - storage_factoryB_gadgets_1 = 200
#
# Inflows_Balanced_for_Factory_A___gadgets___time_1: factoryA_gadgets_1
#  - storage_factoryA_gadgets_1 >= 0
#
# Inflows_Balanced_for_Factory_B___gadgets___time_1: factoryB_gadgets_1
#  - storage_factoryB_gadgets_1 >= 0
#
# Inflows_and_Outflows_of_Production_Equal___gadgets___time_2:
#  factoryA_gadgets_2 + factoryB_gadgets_2 - marketing_gadgets_1
#  + storage_factoryA_gadgets_1 - storage_factoryA_gadgets_2
#  + storage_factoryB_gadgets_1 - storage_factoryB_gadgets_2 = 300
#
# Inflows_Balanced_for_Factory_A___gadgets___time_2: factoryA_gadgets_2
#  + storage_factoryA_gadgets_1 - storage_factoryA_gadgets_2 >= 0
#
# Inflows_Balanced_for_Factory_B___gadgets___time_2: factoryB_gadgets_2
#  + storage_factoryB_gadgets_1 - storage_factoryB_gadgets_2 >= 0
#
# Inflows_and_Outflows_of_Production_Equal___gadgets___time_3:
#  factoryA_gadgets_3 + factoryB_gadgets_3 - marketing_gadgets_2
#  + storage_factoryA_gadgets_2 - storage_factoryA_gadgets_3
#  + storage_factoryB_gadgets_2 - storage_factoryB_gadgets_3 = 295
#
# Inflows_Balanced_for_Factory_A___gadgets___time_3: factoryA_gadgets_3
#  + storage_factoryA_gadgets_2 - storage_factoryA_gadgets_3 >= 0
#
# Inflows_Balanced_for_Factory_B___gadgets___time_3: factoryB_gadgets_3
#  + storage_factoryB_gadgets_2 - storage_factoryB_gadgets_3 >= 0
#
# Inflows_and_Outflows_of_Production_Equal___gadgets___time_4:
#  factoryA_gadgets_4 + factoryB_gadgets_4 - marketing_gadgets_3
#  + storage_factoryA_gadgets_3 - storage_factoryA_gadgets_4
#  + storage_factoryB_gadgets_3 - storage_factoryB_gadgets_4 = 245
#
# Inflows_Balanced_for_Factory_A___gadgets___time_4: factoryA_gadgets_4
#  + storage_factoryA_gadgets_3 - storage_factoryA_gadgets_4 >= 0
#
# Inflows_Balanced_for_Factory_B___gadgets___time_4: factoryB_gadgets_4
#  + storage_factoryB_gadgets_3 - storage_factoryB_gadgets_4 >= 0
#
# Inflows_and_Outflows_of_Production_Equal___gadgets___time_5:
#  factoryA_gadgets_5 + factoryB_gadgets_5 - marketing_gadgets_4
#  + storage_factoryA_gadgets_4 - storage_factoryA_gadgets_5
#  + storage_factoryB_gadgets_4 - storage_factoryB_gadgets_5 = 240
#
# Inflows_Balanced_for_Factory_A___gadgets___time_5: factoryA_gadgets_5
#  + storage_factoryA_gadgets_4 - storage_factoryA_gadgets_5 >= 0
#
# Inflows_Balanced_for_Factory_B___gadgets___time_5: factoryB_gadgets_5
#  + storage_factoryB_gadgets_4 - storage_factoryB_gadgets_5 >= 0
#
# Inflows_and_Outflows_of_Production_Equal___flugels___time_1:
#  factoryA_flugels_1 + factoryB_flugels_1 - storage_factoryA_flugels_1
#  - storage_factoryB_flugels_1 = 140
#
# Inflows_Balanced_for_Factory_A___flugels___time_1: factoryA_flugels_1
#  - storage_factoryA_flugels_1 >= 0
#
# Inflows_Balanced_for_Factory_B___flugels___time_1: factoryB_flugels_1
#  - storage_factoryB_flugels_1 >= 0
#
# Inflows_and_Outflows_of_Production_Equal___flugels___time_2:
#  factoryA_flugels_2 + factoryB_flugels_2 - marketing_flugels_1
#  + storage_factoryA_flugels_1 - storage_factoryA_flugels_2
#  + storage_factoryB_flugels_1 - storage_factoryB_flugels_2 = 175
#
# Inflows_Balanced_for_Factory_A___flugels___time_2: factoryA_flugels_2
#  + storage_factoryA_flugels_1 - storage_factoryA_flugels_2 >= 0
#
# Inflows_Balanced_for_Factory_B___flugels___time_2: factoryB_flugels_2
#  + storage_factoryB_flugels_1 - storage_factoryB_flugels_2 >= 0
#
# Inflows_and_Outflows_of_Production_Equal___flugels___time_3:
#  factoryA_flugels_3 + factoryB_flugels_3 - marketing_flugels_2
#  + storage_factoryA_flugels_2 - storage_factoryA_flugels_3
#  + storage_factoryB_flugels_2 - storage_factoryB_flugels_3 = 205
#
# Inflows_Balanced_for_Factory_A___flugels___time_3: factoryA_flugels_3
#  + storage_factoryA_flugels_2 - storage_factoryA_flugels_3 >= 0
#
# Inflows_Balanced_for_Factory_B___flugels___time_3: factoryB_flugels_3
#  + storage_factoryB_flugels_2 - storage_factoryB_flugels_3 >= 0
#
# Inflows_and_Outflows_of_Production_Equal___flugels___time_4:
#  factoryA_flugels_4 + factoryB_flugels_4 - marketing_flugels_3
#  + storage_factoryA_flugels_3 - storage_factoryA_flugels_4
#  + storage_factoryB_flugels_3 - storage_factoryB_flugels_4 = 235
#
# Inflows_Balanced_for_Factory_A___flugels___time_4: factoryA_flugels_4
#  + storage_factoryA_flugels_3 - storage_factoryA_flugels_4 >= 0
#
# Inflows_Balanced_for_Factory_B___flugels___time_4: factoryB_flugels_4
#  + storage_factoryB_flugels_3 - storage_factoryB_flugels_4 >= 0
#
# Inflows_and_Outflows_of_Production_Equal___flugels___time_5:
#  factoryA_flugels_5 + factoryB_flugels_5 - marketing_flugels_4
#  + storage_factoryA_flugels_4 - storage_factoryA_flugels_5
#  + storage_factoryB_flugels_4 - storage_factoryB_flugels_5 = 230
#
# Inflows_Balanced_for_Factory_A___flugels___time_5: factoryA_flugels_5
#  + storage_factoryA_flugels_4 - storage_factoryA_flugels_5 >= 0
#
# Inflows_Balanced_for_Factory_B___flugels___time_5: factoryB_flugels_5
#  + storage_factoryB_flugels_4 - storage_factoryB_flugels_5 >= 0
#
# Factory_A_Storage_limit___time_1: storage_factoryA_flugels_1
#  + storage_factoryA_gadgets_1 + storage_factoryA_widgets_1 <= 70
#
# Factory_A_Storage_limit___time_2: storage_factoryA_flugels_2
#  + storage_factoryA_gadgets_2 + storage_factoryA_widgets_2 <= 70
#
# Factory_A_Storage_limit___time_3: storage_factoryA_flugels_3
#  + storage_factoryA_gadgets_3 + storage_factoryA_widgets_3 <= 70
#
# Factory_A_Storage_limit___time_4: storage_factoryA_flugels_4
#  + storage_factoryA_gadgets_4 + storage_factoryA_widgets_4 <= 70
#
# Factory_A_Storage_limit___time_5: storage_factoryA_flugels_5
#  + storage_factoryA_gadgets_5 + storage_factoryA_widgets_5 <= 70
#
# Factory_B_Storage_limit___time_1: storage_factoryB_flugels_1
#  + storage_factoryB_gadgets_1 + storage_factoryB_widgets_1 <= 50
#
# Factory_B_Storage_limit___time_2: storage_factoryB_flugels_2
#  + storage_factoryB_gadgets_2 + storage_factoryB_widgets_2 <= 50
#
# Factory_B_Storage_limit___time_3: storage_factoryB_flugels_3
#  + storage_factoryB_gadgets_3 + storage_factoryB_widgets_3 <= 50
#
# Factory_B_Storage_limit___time_4: storage_factoryB_flugels_4
#  + storage_factoryB_gadgets_4 + storage_factoryB_widgets_4 <= 50
#
# Factory_B_Storage_limit___time_5: storage_factoryB_flugels_5
#  + storage_factoryB_gadgets_5 + storage_factoryB_widgets_5 <= 50
#
# Raw_Material_1_Limits___time_1: 178 factoryA_flugels_1
#  + 230 factoryA_gadgets_1 + 194 factoryA_widgets_1 + 170 factoryB_flugels_1
#  + 225 factoryB_gadgets_1 + 188 factoryB_widgets_1 <= 140000
#
# Raw_Material_2_Limits___time_1: 11.6 factoryA_flugels_1
#  + 8.6 factoryA_widgets_1 + 10.8 factoryB_flugels_1 + 9.2 factoryB_widgets_1
#  <= 5000
#
# Raw_Material_1_Limits___time_2: 178 factoryA_flugels_2
#  + 230 factoryA_gadgets_2 + 194 factoryA_widgets_2 + 170 factoryB_flugels_2
#  + 225 factoryB_gadgets_2 + 188 factoryB_widgets_2 <= 140000
#
# Raw_Material_2_Limits___time_2: 11.6 factoryA_flugels_2
#  + 8.6 factoryA_widgets_2 + 10.8 factoryB_flugels_2 + 9.2 factoryB_widgets_2
#  <= 5000
#
# Raw_Material_1_Limits___time_3: 178 factoryA_flugels_3
#  + 230 factoryA_gadgets_3 + 194 factoryA_widgets_3 + 170 factoryB_flugels_3
#  + 225 factoryB_gadgets_3 + 188 factoryB_widgets_3 <= 140000
#
# Raw_Material_2_Limits___time_3: 11.6 factoryA_flugels_3
#  + 8.6 factoryA_widgets_3 + 10.8 factoryB_flugels_3 + 9.2 factoryB_widgets_3
#  <= 5000
#
# Raw_Material_1_Limits___time_4: 178 factoryA_flugels_4
#  + 230 factoryA_gadgets_4 + 194 factoryA_widgets_4 + 170 factoryB_flugels_4
#  + 225 factoryB_gadgets_4 + 188 factoryB_widgets_4 <= 140000
#
# Raw_Material_2_Limits___time_4: 11.6 factoryA_flugels_4
#  + 8.6 factoryA_widgets_4 + 10.8 factoryB_flugels_4 + 9.2 factoryB_widgets_4
#  <= 5000
#
# Raw_Material_1_Limits___time_5: 178 factoryA_flugels_5
#  + 230 factoryA_gadgets_5 + 194 factoryA_widgets_5 + 170 factoryB_flugels_5
#  + 225 factoryB_gadgets_5 + 188 factoryB_widgets_5 <= 140000
#
# Raw_Material_2_Limits___time_5: 11.6 factoryA_flugels_5
#  + 8.6 factoryA_widgets_5 + 10.8 factoryB_flugels_5 + 9.2 factoryB_widgets_5
#  <= 5000
#
# VARIABLES
# 0 <= factoryA_flugels_1 Integer
# 0 <= factoryA_flugels_2 Integer
# 0 <= factoryA_flugels_3 Integer
# 0 <= factoryA_flugels_4 Integer
# 0 <= factoryA_flugels_5 Integer
# 0 <= factoryA_gadgets_1 Integer
# 0 <= factoryA_gadgets_2 Integer
# 0 <= factoryA_gadgets_3 Integer
# 0 <= factoryA_gadgets_4 Integer
# 0 <= factoryA_gadgets_5 Integer
# 0 <= factoryA_widgets_1 Integer
# 0 <= factoryA_widgets_2 Integer
# 0 <= factoryA_widgets_3 Integer
# 0 <= factoryA_widgets_4 Integer
# 0 <= factoryA_widgets_5 Integer
# 0 <= factoryB_flugels_1 Integer
# 0 <= factoryB_flugels_2 Integer
# 0 <= factoryB_flugels_3 Integer
# 0 <= factoryB_flugels_4 Integer
# 0 <= factoryB_flugels_5 Integer
# 0 <= factoryB_gadgets_1 Integer
# 0 <= factoryB_gadgets_2 Integer
# 0 <= factoryB_gadgets_3 Integer
# 0 <= factoryB_gadgets_4 Integer
# 0 <= factoryB_gadgets_5 Integer
# 0 <= factoryB_widgets_1 Integer
# 0 <= factoryB_widgets_2 Integer
# 0 <= factoryB_widgets_3 Integer
# 0 <= factoryB_widgets_4 Integer
# 0 <= factoryB_widgets_5 Integer
# 0 <= marketing_flugels_1 Integer
# 0 <= marketing_flugels_2 Integer
# 0 <= marketing_flugels_3 Integer
# 0 <= marketing_flugels_4 Integer
# 0 <= marketing_gadgets_1 Integer
# 0 <= marketing_gadgets_2 Integer
# 0 <= marketing_gadgets_3 Integer
# 0 <= marketing_gadgets_4 Integer
# 0 <= marketing_widgets_1 Integer
# 0 <= marketing_widgets_2 Integer
# 0 <= marketing_widgets_3 Integer
# 0 <= marketing_widgets_4 Integer
# overtime_factoryA_1 Continuous
# overtime_factoryA_2 Continuous
# overtime_factoryA_3 Continuous
# overtime_factoryA_4 Continuous
# overtime_factoryA_5 Continuous
# overtime_factoryB_1 Continuous
# overtime_factoryB_2 Continuous
# overtime_factoryB_3 Continuous
# overtime_factoryB_4 Continuous
# overtime_factoryB_5 Continuous
# 0 <= storage_factoryA_flugels_1 Integer
# 0 <= storage_factoryA_flugels_2 Integer
# 0 <= storage_factoryA_flugels_3 Integer
# 0 <= storage_factoryA_flugels_4 Integer
# storage_factoryA_flugels_5 = 0 Integer
# 0 <= storage_factoryA_gadgets_1 Integer
# 0 <= storage_factoryA_gadgets_2 Integer
# 0 <= storage_factoryA_gadgets_3 Integer
# 0 <= storage_factoryA_gadgets_4 Integer
# storage_factoryA_gadgets_5 = 0 Integer
# 0 <= storage_factoryA_widgets_1 Integer
# 0 <= storage_factoryA_widgets_2 Integer
# 0 <= storage_factoryA_widgets_3 Integer
# 0 <= storage_factoryA_widgets_4 Integer
# storage_factoryA_widgets_5 = 0 Integer
# 0 <= storage_factoryB_flugels_1 Integer
# 0 <= storage_factoryB_flugels_2 Integer
# 0 <= storage_factoryB_flugels_3 Integer
# 0 <= storage_factoryB_flugels_4 Integer
# storage_factoryB_flugels_5 = 0 Integer
# 0 <= storage_factoryB_gadgets_1 Integer
# 0 <= storage_factoryB_gadgets_2 Integer
# 0 <= storage_factoryB_gadgets_3 Integer
# 0 <= storage_factoryB_gadgets_4 Integer
# storage_factoryB_gadgets_5 = 0 Integer
# 0 <= storage_factoryB_widgets_1 Integer
# 0 <= storage_factoryB_widgets_2 Integer
# 0 <= storage_factoryB_widgets_3 Integer
# 0 <= storage_factoryB_widgets_4 Integer
# storage_factoryB_widgets_5 = 0 Integer
#
#
# Parameter Set
#                           Name  Optimal Value
# 0           factoryA_flugels_1           0.00
# 1           factoryA_flugels_2           0.00
# 2           factoryA_flugels_3           0.00
# 3           factoryA_flugels_4           0.00
# 4           factoryA_flugels_5           0.00
# 5           factoryA_gadgets_1           2.00
# 6           factoryA_gadgets_2           0.00
# 7           factoryA_gadgets_3           3.00
# 8           factoryA_gadgets_4           0.00
# 9           factoryA_gadgets_5           0.00
# 10          factoryA_widgets_1         138.00
# 11          factoryA_widgets_2           1.00
# 12          factoryA_widgets_3           2.00
# 13          factoryA_widgets_4           4.00
# 14          factoryA_widgets_5           0.00
# 15          factoryB_flugels_1         140.00
# 16          factoryB_flugels_2         296.00
# 17          factoryB_flugels_3         362.00
# 18          factoryB_flugels_4         289.00
# 19          factoryB_flugels_5         286.00
# 20          factoryB_gadgets_1         250.00
# 21          factoryB_gadgets_2         259.00
# 22          factoryB_gadgets_3         282.00
# 23          factoryB_gadgets_4         245.00
# 24          factoryB_gadgets_5         239.00
# 25          factoryB_widgets_1           0.00
# 26          factoryB_widgets_2         166.00
# 27          factoryB_widgets_3          74.00
# 28          factoryB_widgets_4         186.00
# 29          factoryB_widgets_5         200.00
# 30         marketing_flugels_1         121.00
# 31         marketing_flugels_2         157.00
# 32         marketing_flugels_3          54.00
# 33         marketing_flugels_4          56.00
# 34         marketing_gadgets_1           0.00
# 35         marketing_gadgets_2           0.00
# 36         marketing_gadgets_3           0.00
# 37         marketing_gadgets_4           0.00
# 38         marketing_widgets_1           1.00
# 39         marketing_widgets_2           0.00
# 40         marketing_widgets_3           0.00
# 41         marketing_widgets_4           0.00
# 42         overtime_factoryA_1           0.00
# 43         overtime_factoryA_2           0.00
# 44         overtime_factoryA_3           0.00
# 45         overtime_factoryA_4           0.00
# 46         overtime_factoryA_5           0.00
# 47         overtime_factoryB_1           0.00
# 48         overtime_factoryB_2           0.00
# 49         overtime_factoryB_3         481.95
# 50         overtime_factoryB_4           0.00
# 51         overtime_factoryB_5           0.00
# 52  storage_factoryA_flugels_1           0.00
# 53  storage_factoryA_flugels_2           0.00
# 54  storage_factoryA_flugels_3           0.00
# 55  storage_factoryA_flugels_4           0.00
# 56  storage_factoryA_flugels_5           0.00
# 57  storage_factoryA_gadgets_1           2.00
# 58  storage_factoryA_gadgets_2           1.00
# 59  storage_factoryA_gadgets_3           1.00
# 60  storage_factoryA_gadgets_4           1.00
# 61  storage_factoryA_gadgets_5           0.00
# 62  storage_factoryA_widgets_1          68.00
# 63  storage_factoryA_widgets_2          69.00
# 64  storage_factoryA_widgets_3           0.00
# 65  storage_factoryA_widgets_4           0.00
# 66  storage_factoryA_widgets_5           0.00
# 67  storage_factoryB_flugels_1           0.00
# 68  storage_factoryB_flugels_2           0.00
# 69  storage_factoryB_flugels_3           0.00
# 70  storage_factoryB_flugels_4           0.00
# 71  storage_factoryB_flugels_5           0.00
# 72  storage_factoryB_gadgets_1          50.00
# 73  storage_factoryB_gadgets_2          10.00
# 74  storage_factoryB_gadgets_3           0.00
# 75  storage_factoryB_gadgets_4           0.00
# 76  storage_factoryB_gadgets_5           0.00
# 77  storage_factoryB_widgets_1           0.00
# 78  storage_factoryB_widgets_2          40.00
# 79  storage_factoryB_widgets_3           0.00
# 80  storage_factoryB_widgets_4           0.00
# 81  storage_factoryB_widgets_5           0.00
